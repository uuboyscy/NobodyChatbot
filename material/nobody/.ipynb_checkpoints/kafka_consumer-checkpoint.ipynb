# %%
'''

從MySQL取得product table
以及 userID，用來創新文件

'''
import pymysql
import pprint

# open connection(host, user, password, database)
host = "uuboyscymysql.clrhltpp3icl.ap-northeast-1.rds.amazonaws.com"
port = int(3306)
user = "food"
password = "food"
db = "food"

conn = pymysql.connect(
    host = host,
    port = port,
    user = user,
    password = password,
    db = db,
    charset='utf8',    
    cursorclass=pymysql.cursors.DictCursor )

print('Connected successfully!')

cursor = conn.cursor()
cursor.execute("SELECT `productName`, `productUnitPrice` from productTable;")

product_dict_list = cursor.fetchall()

print(product_dict_list)

cursor.execute("SELECT `userID` FROM membersInfo;")

userID_dist_list = cursor.fetchall()
userID_list = []
transaction_status_dict = {}

for i in userID_dist_list:
    userID_list.append(i['userID'])
print(userID_list)

for i in userID_list: # i for userID, j for product name
    transaction_status_dict[i] = {}
    for num, j in enumerate(product_dict_list):
        #print(j['productName'])
        transaction_status_dict[i][j['productName']] = [0, product_dict_list[num]['productUnitPrice'], 0, num+1] # quantity, unit price, subtotal
    
print('\n=====\n')
pprint.pprint(transaction_status_dict)

conn.close()
# Out:
# Connected successfully!
# [{'productName': 'Salt', 'productUnitPrice': 40}, {'productName': 'Sauce', 'productUnitPrice': 50}, {'productName': 'Egg', 'productUnitPrice': 30}, {'productName': 'Chicken', 'productUnitPrice': 150}, {'productName': 'Pork', 'productUnitPrice': 170}, {'productName': 'Flour', 'productUnitPrice': 75}, {'productName': 'OliveOil', 'productUnitPrice': 120}, {'productName': 'Cream', 'productUnitPrice': 100}]
# ['U0fe5e2ddf71a138b6e21d4a970592127', 'U19a0dc2519f15c625ea764802cd62202', 'U1e91bf35eb5315bc17da624e46a65c51', 'U26c1d062b5768c0ab8721698973d67b1', 'U2dd03f0598a942d9050eea3c4676f85d', 'U3635a6a27c2907e7e6f1cf2d8dd41a0c', 'U400b95f5a7d6cb62ef336f96b26de6dd', 'U57dae482fd0d30eddb584a0e3e69d7fd', 'U5dc989d65f1897bd44fcbd415b47e164', 'U6d22d8292171bb2cfd96d2b9ef5383a9', 'U7101f9f716cfb37a89a2a09207636b17', 'U7173dc299af6ac3fe7697a75c2a280ad', 'U7cb420838034721c73198cf46a9fb195', 'U7d56a120b59383802416bde5192f0adb', 'U8b575a120d53d40ad98617d52a1ba9b4', 'U96ed7dbbe707db39b8ef85a0c1274631', 'U9a1715c6ffdf0ef2ffe148726d336011', 'U9dfb30bda156b01ce822ca67d4282927', 'Ua0ac6b70d3611ea9d3d4665941dbf3f7', 'Uaefa84530bef60672e135c6cee89341d', 'Uc12878ff30adabf6f390bbad29147153', 'Uc132d7550826d16f3d86f60a24aaae20', 'Uc72bfd5a14b0e6bd6d8a8e78491b6ca3', 'Ucfe8ccde71931f874b974c3b7221ad84', 'Udf8f1c512878156d2bf8d0051d4f2429', 'Ue5148dd83b43580ee1b47aa93a371244', 'Uef7546599902de083b6bbe1d85821323', 'Uf0bca333372b3950aa8b82afdac9a6f3']
#
# =====
#
# {'U0fe5e2ddf71a138b6e21d4a970592127': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U19a0dc2519f15c625ea764802cd62202': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U1e91bf35eb5315bc17da624e46a65c51': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U26c1d062b5768c0ab8721698973d67b1': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U2dd03f0598a942d9050eea3c4676f85d': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U3635a6a27c2907e7e6f1cf2d8dd41a0c': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U400b95f5a7d6cb62ef336f96b26de6dd': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U57dae482fd0d30eddb584a0e3e69d7fd': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U5dc989d65f1897bd44fcbd415b47e164': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U6d22d8292171bb2cfd96d2b9ef5383a9': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U7101f9f716cfb37a89a2a09207636b17': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U7173dc299af6ac3fe7697a75c2a280ad': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U7cb420838034721c73198cf46a9fb195': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U7d56a120b59383802416bde5192f0adb': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U8b575a120d53d40ad98617d52a1ba9b4': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U96ed7dbbe707db39b8ef85a0c1274631': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U9a1715c6ffdf0ef2ffe148726d336011': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'U9dfb30bda156b01ce822ca67d4282927': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Ua0ac6b70d3611ea9d3d4665941dbf3f7': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Uaefa84530bef60672e135c6cee89341d': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Uc12878ff30adabf6f390bbad29147153': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Uc132d7550826d16f3d86f60a24aaae20': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Uc72bfd5a14b0e6bd6d8a8e78491b6ca3': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Ucfe8ccde71931f874b974c3b7221ad84': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Udf8f1c512878156d2bf8d0051d4f2429': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Ue5148dd83b43580ee1b47aa93a371244': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Uef7546599902de083b6bbe1d85821323': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]},
#  'Uf0bca333372b3950aa8b82afdac9a6f3': {'Chicken': [0, 150, 0, 4],
#                                        'Cream': [0, 100, 0, 8],
#                                        'Egg': [0, 30, 0, 3],
#                                        'Flour': [0, 75, 0, 6],
#                                        'OliveOil': [0, 120, 0, 7],
#                                        'Pork': [0, 170, 0, 5],
#                                        'Salt': [0, 40, 0, 1],
#                                        'Sauce': [0, 50, 0, 2]}}

# %%
for i in transaction_status_dict['Ue5148dd83b43580ee1b47aa93a371244']:
    print(i)
# Out:
# Salt
# Sauce
# Egg
# Chicken
# Pork
# Flour
# OliveOil
# Cream

# %%
from kafka import KafkaConsumer, TopicPartition, KafkaClient
import sys
import json
import requests

secretFileContentJson=json.load(open("../line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")


if __name__ == "__main__":
    # 步驟1.設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # Kafka集群在那裡?
        bootstrap_servers=["34.80.39.244:9092"],
        # ConsumerGroup的名稱
        group_id="chatbot_consumer",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
         key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        value_deserializer=bytes.decode,
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )

####################################################


    # 步驟2.指定想要訂閱訊息的topic名稱
    #topic_name = 'U7173*********************0ad'
    item_num_for_each_userID = {}
    for i in userID_list:
        with open('./transaction_status/%s'%(i), 'w', encoding='utf-8') as f:
            outStr = """
            <tr class="success">
            <td>null</td>
            <td>null</td>
            <td>null</td>
            <td>$ null</td>
            <td>$ null</td>
            </tr>
            """
            f.write(outStr)
        item_num_for_each_userID[i] = 1 # 判斷row顏色、是否刪除第一筆null data
        
########################################
        
    # 步驟3.讓Consumer向Kafka集群訂閱指定的topic
    #consumer.subscribe(topics=topic_name)
    consumer.subscribe(pattern='U[0-9a-z]{32}')
    
    # 表格顏色 list
    tcolor = ["success", "warning"]
    num_color = 0
    #new_transaction = 1
     
    outStr = """"""

    # 步驟4.持續的拉取Kafka有進來的訊息
    try:
        print("Start listen incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            
            wmsg = "topic=%s, partition=%s, offset=%s : (key=%s, value=%s) , timestamp=%s" % (topic, partition,
                                                                              offset, msgKey, msgValue, timestamp)
            # 將消費紀錄寫入檔案
            if not msgKey == 'end':
                if item_num_for_each_userID[topic] == 1:
                    with open('./transaction_status/%s'%(topic), 'w', encoding='utf-8') as f:
                        f.write('')
                
                # 製作dataframe
                outStr = """"""
                col = 0
                total = 0
                for product_status in transaction_status_dict[topic]:
                    if transaction_status_dict[topic][product_status][3] == int(msgKey):
                        transaction_status_dict[topic][product_status][0] = int(msgValue)
                        product_qty = transaction_status_dict[topic][product_status][0]
                        product_unit_price = transaction_status_dict[topic][product_status][1]
                        transaction_status_dict[topic][product_status][2] = product_qty * product_unit_price
                        subtotal = transaction_status_dict[topic][product_status][2]
                    else:
                        product_qty = transaction_status_dict[topic][product_status][0]
                        product_unit_price = transaction_status_dict[topic][product_status][1]
                        subtotal = transaction_status_dict[topic][product_status][2]
                    total += subtotal
                    
                    if not product_qty == 0:
                        outStr += """
                            <tr class=%s>
                            <td>%s</td>
                            <td>%s</td>
                            <td>%s</td>
                            <td>$ %s</td>
                            <td>$ %s</td>
                            </tr>
                        """%(tcolor[col%2], col+1,
                                product_status, 
                                product_qty,
                                product_unit_price,
                                subtotal
                            )
                        col += 1
                outStr += """
                    <thead>
                        <tr class="danger">
                        <th>Total</th>
                        <th>-</th>
                        <th>-</th>
                        <th>-</th>
                        <th>$ %s</th>
                        </tr>
                    </thead>
                    """%(total)
                with open('./transaction_status/%s'%(topic), 'w', encoding='utf-8') as f:
                    f.write(outStr)
                
                '''with open('./transaction_status/%s'%(topic), 'a', encoding='utf-8') as f:
                    outStr = """
                        <tr class=%s>
                        <td>%s</td>
                        <td>%s</td>
                        <td>%s</td>
                        <td>$ %s</td>
                        <td>$ null</td>
                        </tr>
                    """%(tcolor[item_num_for_each_userID[topic]%2], item_num_for_each_userID[topic], 
                                                                    product_dict_list[int(msgKey)-1]['productName'],
                                                                    str(msgValue),
                                                                    product_dict_list[int(msgKey)-1]['productUnitPrice']
                        )
                    f.write(outStr)'''
                item_num_for_each_userID[topic] += 1
                
            if msgKey == 'end':
                with open('./transaction_status/%s'%(topic), 'w', encoding='utf-8') as f:
                    outStr = """
                        <tr class="success">
                        <td>null</td>
                        <td>null</td>
                        <td>null</td>
                        <td>$ null</td>
                        <td>$ null</td>
                        </tr>
                    """
                    f.write(outStr)
                # 將該次交易紀錄上傳MySQL
                conn = pymysql.connect(
                        host = host,
                        port = port,
                        user = user,
                        password = password,
                        db = db,
                        charset='utf8',    
                        cursorclass=pymysql.cursors.DictCursor )
                cursor = conn.cursor()
                
                for product_status in transaction_status_dict[topic]:
                    if not transaction_status_dict[topic][product_status][0] == 0:
                        cursor.execute("INSERT INTO transaction SET orderID=%s, productID=%s, userID=%s, productQTY=%s, datetime=FROM_UNIXTIME(%s)",
                                          (int(timestamp/1000),
                                          transaction_status_dict[topic][product_status][3],
                                          topic,
                                          transaction_status_dict[topic][product_status][0],
                                          int(timestamp/1000)
                                          )
                                      )
                        '''sql += "(%s,%s,'%s',%s,FROM_UNIXTIME(%s));"%(
                                                                    int(timestamp/1000),
                                                                    msgKey,
                                                                    topic,
                                                                    transaction_status_dict[topic][product_status][0],
                                                                    int(timestamp/1000)
                                                                    )
                        '''
                        #print('-----%s'%(sql))
                conn.commit()
                conn.close()
                requests.get('https://%s/transaction_commit/%s'%(server_url, topic))
                print('\nFrom : %s\nTransaction Completed!\n'%(topic))
                
                item_num_for_each_userID[topic] = 1
                
            # 秀出metadata與msgKey & msgValue訊息
            print(wmsg)
            
    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        print('Bye!')
        conn.close()
        consumer.close()
# Out:
# Start listen incoming messages ...
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513745 : (key=8, value=1) , timestamp=1551266599276
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=221 : (key=5, value=2) , timestamp=1551266605288
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=131 : (key=1, value=2) , timestamp=1551266607300
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=133 : (key=7, value=1) , timestamp=1551266612310
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=126 : (key=6, value=1) , timestamp=1551266617321
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=129 : (key=5, value=0) , timestamp=1551266621333
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=130 : (key=7, value=2) , timestamp=1551266624334
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513746 : (key=8, value=1) , timestamp=1551266627335
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=222 : (key=7, value=2) , timestamp=1551266632335
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=132 : (key=3, value=2) , timestamp=1551266636336
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=134 : (key=2, value=0) , timestamp=1551266641337
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=127 : (key=5, value=0) , timestamp=1551266647338
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=131 : (key=8, value=0) , timestamp=1551266650339
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=133 : (key=2, value=0) , timestamp=1551266653340
#
# From : U7173dc299af6ac3fe7697a75c2a280ad
# Transaction Completed!
#
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513747 : (key=end, value=1) , timestamp=1551266657341
#
# From : Udf8f1c512878156d2bf8d0051d4f2429
# Transaction Completed!
#
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=223 : (key=end, value=1) , timestamp=1551266667342
#
# From : U1e91bf35eb5315bc17da624e46a65c51
# Transaction Completed!
#
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=134 : (key=end, value=1) , timestamp=1551266671343
#
# From : Uaefa84530bef60672e135c6cee89341d
# Transaction Completed!
#
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=135 : (key=end, value=1) , timestamp=1551266675344
#
# From : U9a1715c6ffdf0ef2ffe148726d336011
# Transaction Completed!
#
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=128 : (key=end, value=1) , timestamp=1551266680344
#
# From : Ua0ac6b70d3611ea9d3d4665941dbf3f7
# Transaction Completed!
#
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=132 : (key=end, value=1) , timestamp=1551266685345
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513748 : (key=8, value=2) , timestamp=1551266707799
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=224 : (key=6, value=0) , timestamp=1551266712811
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=135 : (key=4, value=1) , timestamp=1551266714822
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=136 : (key=3, value=1) , timestamp=1551266718834
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=129 : (key=6, value=1) , timestamp=1551266724847
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=133 : (key=7, value=3) , timestamp=1551266730859
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=136 : (key=6, value=2) , timestamp=1551266732860
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513749 : (key=1, value=1) , timestamp=1551266735861
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=225 : (key=2, value=3) , timestamp=1551266738862
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=137 : (key=4, value=1) , timestamp=1551266741864
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=137 : (key=1, value=0) , timestamp=1551266744865
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=130 : (key=2, value=3) , timestamp=1551266749865
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=134 : (key=3, value=1) , timestamp=1551266754866
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=135 : (key=4, value=2) , timestamp=1551266757867
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513750 : (key=1, value=2) , timestamp=1551266761868
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=226 : (key=4, value=0) , timestamp=1551266766870
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=138 : (key=5, value=0) , timestamp=1551266770871
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=138 : (key=6, value=0) , timestamp=1551266772872
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=131 : (key=4, value=2) , timestamp=1551266777873
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=136 : (key=6, value=1) , timestamp=1551266780875
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513751 : (key=7, value=3) , timestamp=1551266783877
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513752 : (key=1, value=3) , timestamp=1551266786878
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=227 : (key=8, value=1) , timestamp=1551266791878
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=139 : (key=1, value=3) , timestamp=1551266794879
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=139 : (key=4, value=1) , timestamp=1551266797880
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=132 : (key=6, value=2) , timestamp=1551266799881
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=137 : (key=4, value=0) , timestamp=1551266803882
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=140 : (key=5, value=3) , timestamp=1551266805883
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513753 : (key=3, value=2) , timestamp=1551266807884
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=228 : (key=8, value=2) , timestamp=1551266813885
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=140 : (key=1, value=0) , timestamp=1551266817886
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=141 : (key=6, value=0) , timestamp=1551266820887
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=133 : (key=5, value=1) , timestamp=1551266825888
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=138 : (key=1, value=3) , timestamp=1551266828889
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513754 : (key=3, value=3) , timestamp=1551266830890
#
# From : U7173dc299af6ac3fe7697a75c2a280ad
# Transaction Completed!
#
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513755 : (key=end, value=1) , timestamp=1551266834891
#
# From : Udf8f1c512878156d2bf8d0051d4f2429
# Transaction Completed!
#
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=229 : (key=end, value=1) , timestamp=1551266843892
#
# From : U1e91bf35eb5315bc17da624e46a65c51
# Transaction Completed!
#
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=141 : (key=end, value=1) , timestamp=1551266851893
#
# From : Uaefa84530bef60672e135c6cee89341d
# Transaction Completed!
#
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=142 : (key=end, value=1) , timestamp=1551266859894
#
# From : U9a1715c6ffdf0ef2ffe148726d336011
# Transaction Completed!
#
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=134 : (key=end, value=1) , timestamp=1551266869895
#
# From : Ua0ac6b70d3611ea9d3d4665941dbf3f7
# Transaction Completed!
#
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=139 : (key=end, value=1) , timestamp=1551266875896
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513756 : (key=1, value=0) , timestamp=1551268051389
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513757 : (key=2, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513758 : (key=3, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513759 : (key=4, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513760 : (key=5, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513761 : (key=6, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513762 : (key=7, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513763 : (key=8, value=0) , timestamp=1551268051390
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513764 : (key=1, value=2) , timestamp=1551268051393
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=135 : (key=1, value=0) , timestamp=1551268051392
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=136 : (key=2, value=0) , timestamp=1551268051392
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=137 : (key=3, value=0) , timestamp=1551268051392
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=138 : (key=4, value=0) , timestamp=1551268051392
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=139 : (key=5, value=0) , timestamp=1551268051392
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=140 : (key=6, value=0) , timestamp=1551268051392
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=141 : (key=7, value=0) , timestamp=1551268051393
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=142 : (key=8, value=0) , timestamp=1551268051393
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=230 : (key=1, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=231 : (key=2, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=232 : (key=3, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=233 : (key=4, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=234 : (key=5, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=235 : (key=6, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=236 : (key=7, value=0) , timestamp=1551268051390
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=237 : (key=8, value=0) , timestamp=1551268051390
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=140 : (key=1, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=141 : (key=2, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=142 : (key=3, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=143 : (key=4, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=144 : (key=5, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=145 : (key=6, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=146 : (key=7, value=0) , timestamp=1551268051393
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=147 : (key=8, value=0) , timestamp=1551268051393
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=143 : (key=1, value=0) , timestamp=1551268051391
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=144 : (key=2, value=0) , timestamp=1551268051392
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=145 : (key=3, value=0) , timestamp=1551268051392
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=146 : (key=4, value=0) , timestamp=1551268051392
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=147 : (key=5, value=0) , timestamp=1551268051392
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=148 : (key=6, value=0) , timestamp=1551268051392
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=149 : (key=7, value=0) , timestamp=1551268051392
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=150 : (key=8, value=0) , timestamp=1551268051392
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=142 : (key=1, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=143 : (key=2, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=144 : (key=3, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=145 : (key=4, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=146 : (key=5, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=147 : (key=6, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=148 : (key=7, value=0) , timestamp=1551268051391
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=149 : (key=8, value=0) , timestamp=1551268051391
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=238 : (key=5, value=2) , timestamp=1551268057395
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=150 : (key=7, value=2) , timestamp=1551268060396
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=151 : (key=3, value=2) , timestamp=1551268063396
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=143 : (key=7, value=0) , timestamp=1551268066397
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=148 : (key=1, value=2) , timestamp=1551268072398
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513765 : (key=6, value=2) , timestamp=1551268074399
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513766 : (key=8, value=0) , timestamp=1551268077400
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=239 : (key=2, value=1) , timestamp=1551268079401
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=151 : (key=8, value=1) , timestamp=1551268084402
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=152 : (key=7, value=1) , timestamp=1551268089403
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=144 : (key=7, value=3) , timestamp=1551268091404
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=149 : (key=3, value=2) , timestamp=1551268093405
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=150 : (key=4, value=0) , timestamp=1551268098406
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513767 : (key=4, value=1) , timestamp=1551268101407
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=240 : (key=8, value=0) , timestamp=1551268105408
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=152 : (key=1, value=2) , timestamp=1551268108408
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=153 : (key=7, value=2) , timestamp=1551268112409
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=145 : (key=2, value=3) , timestamp=1551268115411
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=151 : (key=6, value=1) , timestamp=1551268121412
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=241 : (key=2, value=0) , timestamp=1551268123413
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513768 : (key=3, value=1) , timestamp=1551268126414
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=242 : (key=2, value=3) , timestamp=1551268128415
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=153 : (key=6, value=1) , timestamp=1551268132416
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=154 : (key=7, value=1) , timestamp=1551268134417
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=146 : (key=2, value=3) , timestamp=1551268138418
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=152 : (key=6, value=0) , timestamp=1551268140419
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513769 : (key=5, value=0) , timestamp=1551268142420
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513770 : (key=4, value=0) , timestamp=1551268146422
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=243 : (key=3, value=2) , timestamp=1551268150423
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=154 : (key=5, value=1) , timestamp=1551268155423
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=155 : (key=8, value=3) , timestamp=1551268157424
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=147 : (key=5, value=3) , timestamp=1551268163425
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=153 : (key=3, value=0) , timestamp=1551268166426
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=244 : (key=4, value=0) , timestamp=1551268169427
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513771 : (key=4, value=0) , timestamp=1551268173428
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=245 : (key=8, value=2) , timestamp=1551268176429
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=155 : (key=7, value=2) , timestamp=1551268179430
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=156 : (key=8, value=3) , timestamp=1551268183431
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=148 : (key=1, value=3) , timestamp=1551268188432
# topic=Ua0ac6b70d3611ea9d3d4665941dbf3f7, partition=0, offset=154 : (key=5, value=0) , timestamp=1551268192433
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=149 : (key=4, value=3) , timestamp=1551268197434
#
# From : U7173dc299af6ac3fe7697a75c2a280ad
# Transaction Completed!
#
# topic=U7173dc299af6ac3fe7697a75c2a280ad, partition=0, offset=513772 : (key=end, value=1) , timestamp=1551268200434
#
# From : Udf8f1c512878156d2bf8d0051d4f2429
# Transaction Completed!
#
# topic=Udf8f1c512878156d2bf8d0051d4f2429, partition=0, offset=246 : (key=end, value=1) , timestamp=1551268202435
#
# From : U1e91bf35eb5315bc17da624e46a65c51
# Transaction Completed!
#
# topic=U1e91bf35eb5315bc17da624e46a65c51, partition=0, offset=156 : (key=end, value=1) , timestamp=1551268211437
#
# From : Uaefa84530bef60672e135c6cee89341d
# Transaction Completed!
#
# topic=Uaefa84530bef60672e135c6cee89341d, partition=0, offset=157 : (key=end, value=1) , timestamp=1551268218439
#
# From : U9a1715c6ffdf0ef2ffe148726d336011
# Transaction Completed!
#
# topic=U9a1715c6ffdf0ef2ffe148726d336011, partition=0, offset=150 : (key=end, value=1) , timestamp=1551268227440
